# %%
import os
import sys

# Path to add
path_to_add = ".."

# Add the path if it's not already in sys.path
if path_to_add not in sys.path:
    sys.path.append(path_to_add)

# %% [markdown]
# # Transcribe Zoom Sessions

# %% [markdown]
# Convert Lecture Sessions to Audios

# %%
# !python codes/indexing/vid_to_aud.py --video_dir ../data/class_sessions/videos --audio_dir ../data/class_sessions/audios

# %% [markdown]
# Transcribe lecture audio

# %%
# !python codes/indexing/aud_to_txt.py --audio_dir ../data/class_sessions/audios --transcript_dir ../data/class_sessions/transcripts

# %% [markdown]
# # Index Documents

# %%
# !python codes/indexing/index_docs.py --root_dir ./data --extensions txt pdf pptx xlsx --persist_directory ./chroma_index
